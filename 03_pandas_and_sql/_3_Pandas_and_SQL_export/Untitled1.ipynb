# %%
import pandas as pd

# %%
# !ls
# Out:
# PandasAndSQL.ipynb                 candidates_nohead.txt
# Untitled.ipynb                     contributors_with_candidate_id.txt
# Untitled1.ipynb                    data
# cancont.db                         pivot_tables.ipynb
# candidates.txt

# %%
files = !ls data

# %%
files
# Out:
# ['births.csv']

# %%
df_general = pd.DataFrame(columns=['year', 'month', 'day', 'gender', 'births'])
for file in files:
    df = pd.read_csv("data/" + file)
    print(df.head())
    df_general = df_general.append(df)
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
df_general
# Out:
#        year month   day gender  births
# 0      1969     1   1.0      F    4046
# 1      1969     1   1.0      M    4440
# 2      1969     1   2.0      F    4454
# 3      1969     1   2.0      M    4548
# 4      1969     1   3.0      F    4548
# 5      1969     1   3.0      M    4994
# 6      1969     1   4.0      F    4440
# 7      1969     1   4.0      M    4520
# 8      1969     1   5.0      F    4192
# 9      1969     1   5.0      M    4198
# 10     1969     1   6.0      F    4710
# 11     1969     1   6.0      M    4850
# 12     1969     1   7.0      F    4646
# 13     1969     1   7.0      M    5092
# 14     1969     1   8.0      F    4800
# 15     1969     1   8.0      M    4934
# 16     1969     1   9.0      F    4592
# 17     1969     1   9.0      M    4842
# 18     1969     1  10.0      F    4852
# 19     1969     1  10.0      M    5190
# 20     1969     1  11.0      F    4580
# 21     1969     1  11.0      M    4598
# 22     1969     1  12.0      F    4126
# ...
